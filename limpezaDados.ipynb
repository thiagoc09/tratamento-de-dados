# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoc09/tratamento-de-dados/blob/main/limpezaDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando o pandas
import pandas as pd

# para não limitar a visualização do número de colunas
pd.set_option('display.max_columns', None)

# %%
# carregando os dados
df = pd.read_csv("http://data.insideairbnb.com/brazil/rj/rio-de-janeiro/2020-06-19/data/listings.csv.gz")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (61,62,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# visualizando as primeiras entradas
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20200619025839   2020-06-19
# 1  21280  https://www.airbnb.com/rooms/21280  20200619025839   2020-06-19
# 2  25026  https://www.airbnb.com/rooms/25026  20200619025839   2020-06-19
# 3  31560  https://www.airbnb.com/rooms/31560  20200619025839   2020-06-19
# 4  35636  https://www.airbnb.com/rooms/35636  20200619025839   2020-06-20
#
#                                                 name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                   Renovated Modern Apt. Near Beach
# 2          Beautiful Modern Decorated Studio in Copa
# 3                   NICE & COZY 1BDR - IPANEMA BEACH
# 4                   Cosy flat close to Ipanema beach
#
#                                              summary  \
# 0  Discounts for long term stays. Please contact ...
# 1  Immaculately renovated top-floor apartment ove...
# ...

# %%
# verificando as entradas da coluna price
df["price"]
# Out:
# 0        $191.00
# 1        $424.00
# 2        $159.00
# 3        $344.00
# 4        $482.00
#           ...
# 35726    $349.00
# 35727     $59.00
# 35728    $145.00
# 35729    $244.00
# 35730    $392.00
# Name: price, Length: 35731, dtype: object

# %%
# tentando converter para float
float("$244.00")

##Vai dar errado pois temos uma string, e também um sinal $
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-4358709801d5> in <module>()
#       1 # tentando converter para float
# ----> 2 float("$244.00")
#       3
#       4 ##Vai dar errado pois temos uma string, e também um sinal $
#
# ValueError: could not convert string to float: '$244.00'

# %%
# associando o valor à variável
valor = "$244.00"

# %%
# limpando a variável
valor = float(valor.replace("$", ""))
print(valor)
# Out:
# 244.0

# %%
# "$244.00" ==> 244.00
def converter_str(minha_string):
    x = minha_string.replace(",", ".")
    x = float(minha_string.replace("$", ""))
    return x

# %%
# criando função lambda 
lambda x: float(x.replace(",","").replace("$", ""))
# Out:
# <function __main__.<lambda>>

# %%
df["price"].apply(lambda x: float(x.replace(",", "").replace("$", "")))
# Out:
# 0        191.0
# 1        424.0
# 2        159.0
# 3        344.0
# 4        482.0
#          ...
# 35726    349.0
# 35727     59.0
# 35728    145.0
# 35729    244.0
# 35730    392.0
# Name: price, Length: 35731, dtype: float64
